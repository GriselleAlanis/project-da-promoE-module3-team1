# %%
import pandas as pd
import numpy as np
import datetime
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("data/bikes.csv", index_col=0)

# %%
df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018  spring   0     1        0        6           0
# 1        2  02-01-2018  spring   0     1        0        0           0
# 2        3  03-01-2018  spring   0     1        0        1           1
# 3        4  04-01-2018  spring   0     1        0        2           1
# 4        5  05-01-2018  spring   0     1        0        3           1
# 5        6  06-01-2018  spring   0     1        0        4           1
# 6        7  07-01-2018  spring   0     1        0        5           1
# 7        8  08-01-2018  spring   0     1        0        6           0
# 8        9  09-01-2018  spring   0     1        0        0           0
# 9       10  10-01-2018  spring   0     1        0        1           1
#
#    weathersit  temp  atemp   hum  windspeed  casual  registered   cnt
# 0           2 14.11  18.18 80.58      10.75     331         654   985
# ...

# %%
df.describe().T
# Out:
#             count    mean     std   min     25%     50%     75%     max
# instant    730.00  365.50  210.88  1.00  183.25  365.50  547.75  730.00
# yr         730.00    0.50    0.50  0.00    0.00    0.50    1.00    1.00
# mnth       730.00    6.53    3.45  1.00    4.00    7.00   10.00   12.00
# holiday    730.00    0.03    0.17  0.00    0.00    0.00    0.00    1.00
# weekday    730.00    3.00    2.01  0.00    1.00    3.00    5.00    6.00
# workingday 730.00    0.68    0.47  0.00    0.00    1.00    1.00    1.00
# weathersit 730.00    1.39    0.54  1.00    1.00    1.00    2.00    3.00
# temp       730.00   20.32    7.51  2.42   13.81   20.47   26.88   35.33
# atemp      730.00   23.73    8.15  3.95   16.89   24.37   30.45   42.04
# hum        730.00   62.77   14.24  0.00   52.00   62.62   72.99   97.25
# windspeed  730.00   12.76    5.20  1.50    9.04   12.13   15.63   34.00
# casual     730.00  849.25  686.48  2.00  316.25  717.00 1096.50 3410.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    object
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(10), object(2)
# memory usage: 97.0+ KB

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["season"].value_counts()
# Out:
# season
# autumn    188
# summer    184
# spring    180
# winter    178
# Name: count, dtype: int64

# %%
columns = df.columns

# %%
for col in columns:
    print(f'{col} : {len(df[col].unique())}')
    print('--------------------------')
# Out:
# instant : 730
# --------------------------
# dteday : 730
# --------------------------
# season : 4
# --------------------------
# yr : 2
# --------------------------
# mnth : 12
# --------------------------
# holiday : 2
# --------------------------
# weekday : 7
# --------------------------
# workingday : 2
# --------------------------
# weathersit : 3
# --------------------------
# temp : 498
# --------------------------
# atemp : 689
# --------------------------
# hum : 594
# --------------------------
# windspeed : 649
# --------------------------
# casual : 605
# --------------------------
# registered : 678
# --------------------------
# cnt : 695
# --------------------------

# %% [markdown]
# <p>Nuestra variable respuesta va a ser CNT</p>

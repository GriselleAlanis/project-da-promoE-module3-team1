# %% [markdown]
# ESTANDARIZACIÓN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import researchpy as rp
import math

from scipy import stats
import researchpy as rp
from scipy.stats import levene
from scipy.stats import chi2_contingency
from sklearn.preprocessing import RobustScaler


plt.rcParams["figure.figsize"] = (10,8)
pd.options.display.max_columns = None

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_pickle('../data/bikes_limpieza_sin_totales.pkl')
df.head(2)
# Out:
#        fecha  estacion   año  mes     festivo  dia     laborable    meteo  \
# 0 2018-01-01  invierno  2018  ene     festivo  lun  no laborable  nublado
# 1 2018-01-02  invierno  2018  ene  no festivo  mar     laborable  nublado
#
#    temperatura  sensacion_termica  humedad  velo_viento  usu_casuales  \
# 0    14.110847           18.18125  80.5833    10.749882           331
# 1    14.902598           17.68695  69.6087    16.652113           131
#
#    usu_registrados
# 0              654
# 1              670

# %% [markdown]
# Vamos a eliminar la VP numérica "temperatura" que vimos en visualización que correlacionaba muy alto (0.99) con sensación térmica.
# Vamos a eliminar de nuestro modelo predictivo la V "usu_casuales" porque aquí no aplica como VP.

# %%
df.drop(["sensacion_termica", "usu_registrados"], axis= 1, inplace= True)

# %%
df.head()
# Out:
#        fecha  estacion   año  mes     festivo  dia     laborable        meteo  \
# 0 2018-01-01  invierno  2018  ene     festivo  lun  no laborable      nublado
# 1 2018-01-02  invierno  2018  ene  no festivo  mar     laborable      nublado
# 2 2018-01-03  invierno  2018  ene  no festivo  mie     laborable  buen tiempo
# 3 2018-01-04  invierno  2018  ene  no festivo  jue     laborable  buen tiempo
# 4 2018-01-05  invierno  2018  ene  no festivo  vie     laborable  buen tiempo
#
#    temperatura  humedad  velo_viento  usu_casuales
# 0    14.110847  80.5833    10.749882           331
# 1    14.902598  69.6087    16.652113           131
# 2     8.050924  43.7273    16.636703           120
# 3     8.200000  59.0435    10.739832           108
# 4     9.305237  43.6957    12.522300            82

# %%
numericas = df.select_dtypes(include = np.number).drop("usu_casuales", axis= 1)
numericas.head(2)
# Out:
#    temperatura  humedad  velo_viento
# 0    14.110847  80.5833    10.749882
# 1    14.902598  69.6087    16.652113

# %%
robust = RobustScaler()
robust.fit(numericas)
X_robust = robust.transform(numericas)
numericas_robust = pd.DataFrame(X_robust, columns = numericas.columns)
numericas_robust.head(2)
# Out:
#    temperatura   humedad  velo_viento
# 0    -0.486274  0.858854    -0.208909
# 1    -0.425690  0.331548     0.687550

# %%
df_robust = df.copy()
df_robust[numericas_robust.columns] = numericas_robust

# %%
df_robust.head(2)
# Out:
#        fecha  estacion   año  mes     festivo  dia     laborable    meteo  \
# 0 2018-01-01  invierno  2018  ene     festivo  lun  no laborable  nublado
# 1 2018-01-02  invierno  2018  ene  no festivo  mar     laborable  nublado
#
#    temperatura   humedad  velo_viento  usu_casuales
# 0    -0.486274  0.858854    -0.208909           331
# 1    -0.425690  0.331548     0.687550           131

# %%
# Guardamos el df normalizado:

df_robust.to_pickle('../data/bikes_casuales_estand.pkl')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import researchpy as rp

pd.options.display.max_columns = None

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_pickle("../data/bikes_limpieza_sin_totales.pkl")
df.head(2)
# Out:
#        fecha  estacion   año  mes     festivo  dia     laborable    meteo  \
# 0 2018-01-01  invierno  2018  ene     festivo  lun  no laborable  nublado
# 1 2018-01-02  invierno  2018  ene  no festivo  mar     laborable  nublado
#
#    temperatura  sensacion_termica  humedad  velo_viento  usu_casuales  \
# 0    14.110847           18.18125  80.5833    10.749882           331
# 1    14.902598           17.68695  69.6087    16.652113           131
#
#    usu_registrados
# 0              654
# 1              670

# %%
plt.figure(figsize=(7, 5))

sns.histplot(df["usu_casuales"], bins=20, color="skyblue", edgecolor="steelblue", kde=True)

plt.title("Distribución casuales")
plt.xlabel("Nº Alquileres usuarios causales")
plt.ylabel("Frecuencia")
plt.savefig("../img/distribucion_casuales.png")

# %% [markdown]
# Vamos a comprobar las relaciones entre las VP numéricas y la VR:

# %%
fig, axes = plt.subplots(2, 3, figsize = (20, 10))

axes = axes.flat

numericas = df.select_dtypes(include=np.number)

columnas_numeric = numericas.columns
columnas_numeric = columnas_numeric.drop("usu_casuales")

for i, colum in enumerate(columnas_numeric):
    sns.regplot(
        x = df[colum], 
        y = df["usu_casuales"], 
        color = "gray", 
        marker = ".", 
        scatter_kws = {"alpha": 0.4}, 
        line_kws = {"color": "skyblue", "alpha": 0.7 }, 
        ax = axes[i])
    
    axes[i].set_title(f"Alquiler causales vs {colum}", fontsize = 10, fontweight = "bold")
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")
    
fig.tight_layout()
fig.delaxes(axes[-1])
plt.savefig("../img/distribucion_numericas_casuales.png");

# %% [markdown]
# Comprobamos la normalidad de cada VP numérica

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 7))
axes = axes.flat

num = df.select_dtypes(include = np.number).columns
num = num.drop(["usu_casuales", "usu_registrados"])

for i, colum in enumerate(num):
    sns.histplot(
        data = df,
        x = colum,
        kde = True,
        color = "skyblue",
        line_kws = {"linewidth": 2},
        alpha = 0.5,
        ax = axes[i])
    axes[i].set_title(colum, fontsize = 10, fontweight = "bold")
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")
    fig.tight_layout()
fig.delaxes(axes[-1])
plt.savefig("../img/distribucion_numericas.png");

# %% [markdown]
# Calculamos correlación de variables numéricas

# %%
df_numericas = df.select_dtypes(include = np.number)

# %%
df_numericas.cov()
# Out:
#                    temperatura  sensacion_termica      humedad  velo_viento  \
# temperatura          56.350979          60.674105    12.979953    -6.169865
# sensacion_termica    60.674105          66.427517    15.639782    -7.786743
# humedad              12.979953          15.639782   195.738171   -16.628026
# velo_viento          -6.169865          -7.786743   -16.628026    26.996761
# usu_casuales       2796.813593        3040.124429  -852.678361  -599.212506
# usu_registrados    6316.089253        6911.516931 -2505.268579 -1766.034199
#
#                     usu_casuales  usu_registrados
# temperatura          2796.813593     6.316089e+03
# sensacion_termica    3040.124429     6.911517e+03
# humedad              -852.678361    -2.505269e+03
# velo_viento          -599.212506    -1.766034e+03
# usu_casuales       471254.618141     4.220196e+05
# usu_registrados    422019.595513     2.432847e+06

# %%
df_numericas.corr()
# Out:
#                    temperatura  sensacion_termica   humedad  velo_viento  \
# temperatura           1.000000           0.991696  0.123590    -0.158186
# sensacion_termica     0.991696           1.000000  0.137157    -0.183876
# humedad               0.123590           0.137157  1.000000    -0.228743
# velo_viento          -0.158186          -0.183876 -0.228743     1.000000
# usu_casuales          0.542731           0.543362 -0.088781    -0.167995
# usu_registrados       0.539436           0.543678 -0.114805    -0.217914
#
#                    usu_casuales  usu_registrados
# temperatura            0.542731         0.539436
# sensacion_termica      0.543362         0.543678
# humedad               -0.088781        -0.114805
# velo_viento           -0.167995        -0.217914
# usu_casuales           1.000000         0.394137
# usu_registrados        0.394137         1.000000

# %%
sns.heatmap(df_numericas.corr(), 
            cmap = "Blues", 
           annot = True, vmax = 1, vmin = -1);
plt.savefig('../img/heatmap_correl.png', dpi = 300)

# %% [markdown]
# Vamos ahora a ver cómo se distribuye la VR según las VP categóricas:

# %%
mes = {"ene": 0, 
       "feb": 0, 
       "mar": 2, 
       "abr": 3, 
       "may": 3, 
       "jun": 4, 
       "jul": 5, 
       "ago": 5, 
       "sep": 4,
       "oct": 3, 
       "nov": 2, 
       "dic": 1}

festivo = {"festivo": 1, "no festivo": 0}

dia = {"lun": 3, 
       "mar": 2, 
       "mie": 1, 
       "jue": 1, 
       "vie": 0, 
       "sab": 1, 
       "dom": 2}

meteo = {"nublado": 1, 
         "buen tiempo": 2, 
         "ligeramente mal tiempo": 0}

año = {2018: 0,
       2019: 1}

# %%
df.groupby("dia")["usu_casuales"].median().sort_values()
# Out:
# dia
# vie     537.5
# sab     610.0
# jue     628.5
# mie     666.5
# dom     876.5
# mar     982.0
# lun    1434.0
# Name: usu_casuales, dtype: float64

# %%
categoricas = df.select_dtypes(include=["object", "category"])

fig, axes = plt.subplots(4, 2, figsize=(15,15))
axes = axes.flat
for indice, columna in enumerate(categoricas.columns):
    sns.boxplot(x = categoricas[columna], y = 'usu_casuales', data = df, ax = axes[indice], palette = "Blues");
plt.tight_layout()
fig.delaxes(axes[-1])
plt.savefig("../img/distribucion_categ_casuales.png")

# %% [markdown]
# - No tienen orden variables =  laborable
# - Tienen orden variables = meteo, festivo, dia, mes, estacion

# %% [markdown]
# Independencia variables categóricas

# %%
categoricas_col = df.select_dtypes(include= ["object", "bool"]).columns
df_chis = pd.DataFrame(columns= categoricas_col, index = categoricas_col)

from itertools import combinations
combinaciones = list(combinations(categoricas_col,2))
for i in combinaciones:
    crosstab, test_results, expected = rp.crosstab(df[i[0]], df[i[1]],
                                               test= "chi-square",
                                               expected_freqs= True,
                                               prop= "cell")
    df_chis.loc[i[0], i[1]] = test_results.loc[2, 'results']
    df_chis.loc[i[1], i[0]] = test_results.loc[2, 'results']
    df_chis.loc[i[0], i[0]] = 1.00
    df_chis.loc[i[1], i[1]] = 1.00
df_chis = df_chis.astype('float')
df_chis.dtypes
cmap = sns.diverging_palette(349, 250, sep=150, as_cmap=True)
sns.heatmap(df_chis,
           cmap = cmap,
           annot = True,
           vmin= -1,
           vmax= 1)
plt.savefig("../img/heatmap_categoricas.png");

# %% [markdown]
# **NOTA: para los cálculos de predicciones NO tendremos en cuenta las columnas estación y laborable como variables predictoras por ser redundantes con mes y día.**
